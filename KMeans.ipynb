# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Carregar dados genéricos
categories = ['comp.graphics', 'rec.sport.hockey', 'sci.med', 'talk.politics.guns']
newsgroups = fetch_20newsgroups(subset='all', categories=categories, remove=('headers', 'footers', 'quotes'))
texts = newsgroups.data

# Converter texto em vetores TF-IDF
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(texts)

# Determinar o número ideal de clusters (método do cotovelo)
def find_optimal_clusters(data, max_k):
    scores = []
    for k in range(2, max_k):
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(data)
        scores.append(kmeans.inertia_)
    plt.plot(range(2, max_k), scores, marker='o')
    plt.title("Método do Cotovelo")
    plt.xlabel("Número de Clusters")
    plt.ylabel("Inércia")
    plt.show()

find_optimal_clusters(X, 10)

# Treinar o modelo com o número de clusters ideal
num_clusters = 4  # Ajuste com base no gráfico
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X)

# Verificar os clusters
clusters = kmeans.labels_

# Mostrar exemplos de cada cluster
for cluster in range(num_clusters):
    print(f"\nCluster {cluster}:")
    for i, text in enumerate([texts[i] for i in range(len(clusters)) if clusters[i] == cluster][:5]):
        print(f"  {i+1}: {text[:200]}...")
# Out:
# Cluster 0:
#   1: RFD
#                           Request For Discussion
#                                 for the
#                           OPEN  TELEMATIC GROUP
#
#                                   OTG
#
# I have proposed the...
#   2:
# Is there a precompiled version of hp2xx for DOS out there - prefereably
# for 386/486?
# ...
#   3: Please help with MPEG description or sources:decoders &
# encoders. Great thanks in advance.
# ...
#   4: I'm making a customized paint program in DOS and need an algorithm
# for reading bitmap files like GIF, PCX, or BMP.  Does anyone have
# such an algorithm?  I've tried copying one out of a book for readin...
#   5:
#
#
#
# The alt.* hierarchie is created for 2 purposes:
# 1. For groups which do not fit under the comp.* or other 'official'
#   hierarchies
# 2. For the fast creation of hot new newsgroups like alt.gulf.war
#
# ...
#
# Cluster 1:
#   1:
# The domain address of the WHO is:  who.arcom.ch
# So try sending email to  postmaster@who.arcom.ch
#
# Josh
# backon@VMS.HUJI.AC.IL
#
#
#
#
#
# ...
#   2:
#
#
# Chronic persistent hepatitis is usually diagnosed when someone does a liver
# biopsy on a patient that has persistently elevated serum transaminases months
# after a bout of acute viral hepatitis, or w...
#   3: Playoff leaders as of April 19, 1993
#
#     Player       Team   GP  G   A  Pts +/- PIM
#
#     M.Lemieux    PIT     1   2   2   4   0   0
#     Juneau       BOS     1   1   3   4   0   0
#     Noonan       CHI...
#   4:
#
#
# I would have chosen Alex Zhitnik for biggest suprise.  They
# did expect that he would become a great defenseman, but I don't
# think anyone knew that he was going to be this impressive in his
# rookie ...
#   5:
# There was an article in one of the Toronto papers about this a few
# months ago...probably the Globe and Mail...
#
# ...any ethical "journalist", even a sports journalist should not
# accept free meals from...
#
# Cluster 2:
#   1: Article in this morning's Houston Post...."negotiators send food to
# rebellious inmates as humanitarian gesture"...speaking about the Ohio prison
# riot where they have killed at least one of the hostage...
#   2:
# I knew that Cutie would sell us out.  Full-blooded Democrat, he is :-)
#
# Seriously folks, if it can happen here (remember?  we all got gun racks on
# our 4x4s), it can happen anywhere.  Now to get that ...
#   3:
# ..
#
# funny, if Koresh did say that, he was quoting St. Paul. of course,
# the early Christians were persecuted too. if Koresh is a loony
# because he quotes the Bible, how long is it before mainstream
# ...
#   4:
# "Widely reported", eh?  Remember, this has had a news blackout since day 2.
# The FBI is the single, sole, source of these rumors.  It may be the truth, but
# it may not be.  We may never know.  We MUS...
#   5:
#
#
#
#
# I don't think your objection is beyond the bounds of rationality.  The
# right mentioned in the bill is already established under the Second
# Amendment; the bill should be reworded to reaffirm the S...
#
# Cluster 3:
#   1: If ESPN pisses you off, call them - they do respond to calls. Last night I
# called when they said they were cutting to baseball and we couldn't see the
# sudden-death overtime for the BUffalo game. Appar...
#   2:
#
# Well that's really great Pat.  I guess since you've played a little you thereby
# qualify as an expert.  Especially since you watch all the games on t.v.  All
# that qualifies you as is a armchair qu...
#   3:
# Okay, here's the down side of the ESPN deal: no additional coverage.
# With a split contract, SCA could have at least gotten at leftovers
# like Canucks-Jets, Caps-whoever and Red Wings-Leafs (or whoever...
#   4:       As I recall, the Penguins and Devils tied for third place last year
# with identical records, as well.  Poor Devils -- they always get screwed.
# Yet, they should put a scare into Pittsburgh.  They ...
#   5: Do the Isles have another defenseman to insert into the line-up besides
# Pilon??? Once again, last night's STUPID penalty put the Isles in a hole for the
# remainder of regulation and 2 minutes into over...

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Carregando os dados do dataset.
categories = ['comp.graphics', 'rec.sport.hockey', 'sci.med', 'talk.politics.guns']
newsgroups = fetch_20newsgroups(subset='all', categories=categories, remove=('headers', 'footers', 'quotes'))
texts = newsgroups.data

# %%
# Convertendo o texto em vetores
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(texts)

# %%
# Determinar o número ideal de clusters (método do cotovelo)
def find_optimal_clusters(data, max_k):
    scores = []
    for k in range(2, max_k):
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(data)
        scores.append(kmeans.inertia_)
    plt.plot(range(2, max_k), scores, marker='o')
    plt.title("Método do Cotovelo")
    plt.xlabel("Número de Clusters")
    plt.ylabel("Inércia")
    plt.show()

find_optimal_clusters(X, 10)

# %%
# Treinar o modelo com o número de clusters ideal
num_clusters = 4
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Verificar os clusters
clusters = kmeans.labels_

# %%
# Mostrar exemplos de cada cluster
for cluster in range(num_clusters):
    print(f"\nCluster {cluster}:")
    for i, text in enumerate([texts[i] for i in range(len(clusters)) if clusters[i] == cluster][:5]):
        print(f"  {i+1}: {text[:200]}...")
# Out:
# Cluster 0:
#   1: RFD
#                           Request For Discussion
#                                 for the
#                           OPEN  TELEMATIC GROUP
#
#                                   OTG
#
# I have proposed the...
#   2:
# Is there a precompiled version of hp2xx for DOS out there - prefereably
# for 386/486?
# ...
#   3: Please help with MPEG description or sources:decoders &
# encoders. Great thanks in advance.
# ...
#   4: I'm making a customized paint program in DOS and need an algorithm
# for reading bitmap files like GIF, PCX, or BMP.  Does anyone have
# such an algorithm?  I've tried copying one out of a book for readin...
#   5:
#
#
#
# The alt.* hierarchie is created for 2 purposes:
# 1. For groups which do not fit under the comp.* or other 'official'
#   hierarchies
# 2. For the fast creation of hot new newsgroups like alt.gulf.war
#
# ...
#
# Cluster 1:
#   1:
# The domain address of the WHO is:  who.arcom.ch
# So try sending email to  postmaster@who.arcom.ch
#
# Josh
# backon@VMS.HUJI.AC.IL
#
#
#
#
#
# ...
#   2:
#
#
# Chronic persistent hepatitis is usually diagnosed when someone does a liver
# biopsy on a patient that has persistently elevated serum transaminases months
# after a bout of acute viral hepatitis, or w...
#   3: Playoff leaders as of April 19, 1993
#
#     Player       Team   GP  G   A  Pts +/- PIM
#
#     M.Lemieux    PIT     1   2   2   4   0   0
#     Juneau       BOS     1   1   3   4   0   0
#     Noonan       CHI...
#   4:
#
#
# I would have chosen Alex Zhitnik for biggest suprise.  They
# did expect that he would become a great defenseman, but I don't
# think anyone knew that he was going to be this impressive in his
# rookie ...
#   5:
# There was an article in one of the Toronto papers about this a few
# months ago...probably the Globe and Mail...
#
# ...any ethical "journalist", even a sports journalist should not
# accept free meals from...
#
# Cluster 2:
#   1: Article in this morning's Houston Post...."negotiators send food to
# rebellious inmates as humanitarian gesture"...speaking about the Ohio prison
# riot where they have killed at least one of the hostage...
#   2:
# I knew that Cutie would sell us out.  Full-blooded Democrat, he is :-)
#
# Seriously folks, if it can happen here (remember?  we all got gun racks on
# our 4x4s), it can happen anywhere.  Now to get that ...
#   3:
# ..
#
# funny, if Koresh did say that, he was quoting St. Paul. of course,
# the early Christians were persecuted too. if Koresh is a loony
# because he quotes the Bible, how long is it before mainstream
# ...
#   4:
# "Widely reported", eh?  Remember, this has had a news blackout since day 2.
# The FBI is the single, sole, source of these rumors.  It may be the truth, but
# it may not be.  We may never know.  We MUS...
#   5:
#
#
#
#
# I don't think your objection is beyond the bounds of rationality.  The
# right mentioned in the bill is already established under the Second
# Amendment; the bill should be reworded to reaffirm the S...
#
# Cluster 3:
#   1: If ESPN pisses you off, call them - they do respond to calls. Last night I
# called when they said they were cutting to baseball and we couldn't see the
# sudden-death overtime for the BUffalo game. Appar...
#   2:
#
# Well that's really great Pat.  I guess since you've played a little you thereby
# qualify as an expert.  Especially since you watch all the games on t.v.  All
# that qualifies you as is a armchair qu...
#   3:
# Okay, here's the down side of the ESPN deal: no additional coverage.
# With a split contract, SCA could have at least gotten at leftovers
# like Canucks-Jets, Caps-whoever and Red Wings-Leafs (or whoever...
#   4:       As I recall, the Penguins and Devils tied for third place last year
# with identical records, as well.  Poor Devils -- they always get screwed.
# Yet, they should put a scare into Pittsburgh.  They ...
#   5: Do the Isles have another defenseman to insert into the line-up besides
# Pilon??? Once again, last night's STUPID penalty put the Isles in a hole for the
# remainder of regulation and 2 minutes into over...

# %%
# Reduzir os dados para 2 dimensões usando PCA
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X.toarray())

# Plotar os clusters
plt.figure(figsize=(10, 7))
for cluster in range(num_clusters):
    plt.scatter(
        X_pca[kmeans.labels_ == cluster, 0],
        X_pca[kmeans.labels_ == cluster, 1],
        label=f"Cluster {cluster}"
    )

plt.title("Visualização dos Clusters")
plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")
plt.legend()
plt.show()
